# %%
import pandas as pd
import datetime
import ast

news = pd.read_csv("news.csv")
price = pd.read_csv("price.csv")

# %%
result = open("result.txt", "r")
result_lst = ast.literal_eval(result.readline())
result_date = {}

for item in result_lst:
    result_date[item["ticker"]] = item["newsStartDate"]
result_date
# Out:
# {'ABBV': '2016-08-01',
#  'ABT': '2016-07-28',
#  'ADM': '2016-06-27',
#  'ADP': '2016-08-02',
#  'AFL': '2016-07-25',
#  'ALB': '2016-07-13',
#  'AMCR': '2020-01-14',
#  'AOS': '2016-07-26',
#  'APD': '2016-07-29',
#  'ATO': '2016-10-28',
#  'BDX': '2016-07-15',
#  'BEN': '2016-07-28',
#  'BF.B': '2018-01-04',
#  'CAH': '2016-07-13',
#  'CAT': '2016-07-27',
#  'CB': '2016-07-26',
#  'CINF': '2016-07-18',
#  'CL': '2016-08-01',
#  'CLX': '2016-07-01',
#  'CTAS': '2016-07-19',
#  'CVX': '2016-07-13',
#  'DOV': '2016-07-19',
#  'ECL': '2016-06-01',
#  'ED': '2016-07-25',
#  'EMR': '2016-07-21',
#  'ESS': '2016-09-28',
#  'EXPD': '2016-10-14',
#  'FRT': '2016-07-13',
#  'GD': '2016-07-13',
#  'GPC': '2016-08-26',
#  'GWW': '2016-06-29',
#  'HRL': '2016-05-18',
#  'ITW': '2016-07-26',
#  'JNJ': '2016-05-17',
#  'KMB': '2016-07-20',
#  'KO': '2016-07-07',
#  'LEG': '2016-07-08',
#  'LIN': '2019-04-30',
#  'LOW': '2016-08-04',
#  'MCD': '2016-07-07',
#  'MDT': '2016-07-05',
#  'MKC': '2016-06-14',
#  'MMM': '2016-07-26',
#  'NUE': '2016-07-01',
#  'O': '2016-08-02',
#  'PBCT': '2016-06-27',
#  'PEP': '2016-07-07',
#  'PG': '2016-07-22',
#  'PNR': '2016-07-19',
#  'PPG': '2016-07-07',
#  'ROP': '2016-07-21',
#  'ROST': '2016-06-22',
#  'SHW': '2016-07-22',
#  'SPGI': '2016-08-01',
#  'SWK': '2016-07-15',
#  'SYY': '2016-08-03',
#  'T': '2016-07-06',
#  'TGT': '2016-06-22',
#  'TROW': '2016-06-30',
#  'UTX': '2016-07-08',
#  'VFC': '2016-07-08',
#  'WBA': '2016-07-07',
#  'WMT': '2016-06-29',
#  'XOM': '2016-07-13'}

# %%
def merge_dataframe(news_csv, price_csv, cut_date):
    
    news_data = news_csv.loc[:, ['ticker', 'date', 'title','short_description']]
    news_data = news_data.drop_duplicates()
    # aggregate all title and short description info on the same date and merge the datadrame
    news_data = news_data.groupby(['ticker','date'])[['title','short_description']].agg(list)
    
    price_data = price_csv.loc[:, ['ticker', 'date', 'close']]
    price_data = price_data.drop_duplicates()
    df = pd.merge(news_data, price_data, how="outer", on=['ticker', 'date'])

    df = df.sort_values(['ticker', 'date'], ascending=[True, True])
    df = df.fillna(method='ffill')
    
    for name in df['ticker'].unique().tolist():
        if name in cut_date:
            df = df.drop(df[(df['ticker'] == name) & (df['date'] < cut_date[name] )].index)
    df.reset_index(inplace=True)
    del df['index']
    return df

# %%
df = merge_dataframe(news,price,result_date)
df
# Out:
#       ticker        date                                              title  \
# 0       ABBV  2016-08-01                 [Company News for August 01, 2016]
# 1       ABBV  2016-08-02                 [Company News for August 01, 2016]
# 2       ABBV  2016-08-03                 [Company News for August 01, 2016]
# 3       ABBV  2016-08-04  [Healthcare Dividend Growth Stocks: Part 1, ET...
# 4       ABBV  2016-08-05  [Elliott Associates sues AbbVie over failed bi...
# ...      ...         ...                                                ...
# 53107    XOM  2020-04-01  [Trump warns of ‘heavy price’ if Iran attacks ...
# 53108    XOM  2020-04-02  [Oil in Sudden U-Turn After Trump Touts Produc...
# 53109    XOM  2020-04-03  [Trump Faces Bitterly Divided Oil Producers in...
# 53110    XOM  2020-04-04  [Exclusive: Honeywell Pressures Suppliers To C...
# 53111    XOM  2020-04-05  [The Oil Giant Drowning In Debt, Big Oil Raise...
#
#                                        short_description  close
# 0      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.94
# 1      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.78
# 2      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.57
# 3      [Healthcare Dividend Growth Stocks: Part 1, ET...  66.10
# 4      [Elliott Associates sues AbbVie over failed bi...  66.54
# ...                                                  ...    ...
# 53107  [President Donald Trump warned Iran on Wednesd...  37.53
# 53108  [Can Donald Trump achieve what OPEC itself cou...  40.40
# 53109  [(Bloomberg) -- In Saudi Arabia, there is one ...  39.21
# 53110  [Honeywell, the big industrial and aerospace f...  39.21
# 53111  [Oil major ExxonMobil has not changed its cape...  39.21
#
# [53112 rows x 5 columns]

# %%
def set_label(day, df):
    
    # create shiftday price column 
    df["shiftday"] = df["close"].shift(-day, axis = 0)
    df = df.fillna(list(df["close"])[-1])
    
    # create price difference column
    df["price_diff"] = df["shiftday"] - df["close"]
    
    # create price difference column
    df["label"] = df["price_diff"].apply(lambda x: 1 if x > 0 else 0)
    
    return df

# %%
label_df = set_label(5, df)
label_df
# Out:
#       ticker        date                                              title  \
# 0       ABBV  2016-08-01                 [Company News for August 01, 2016]
# 1       ABBV  2016-08-02                 [Company News for August 01, 2016]
# 2       ABBV  2016-08-03                 [Company News for August 01, 2016]
# 3       ABBV  2016-08-04  [Healthcare Dividend Growth Stocks: Part 1, ET...
# 4       ABBV  2016-08-05  [Elliott Associates sues AbbVie over failed bi...
# ...      ...         ...                                                ...
# 53107    XOM  2020-04-01  [Trump warns of ‘heavy price’ if Iran attacks ...
# 53108    XOM  2020-04-02  [Oil in Sudden U-Turn After Trump Touts Produc...
# 53109    XOM  2020-04-03  [Trump Faces Bitterly Divided Oil Producers in...
# 53110    XOM  2020-04-04  [Exclusive: Honeywell Pressures Suppliers To C...
# 53111    XOM  2020-04-05  [The Oil Giant Drowning In Debt, Big Oil Raise...
#
#                                        short_description  close  shiftday  \
# 0      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.94     66.54
# 1      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.78     66.34
# 2      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.57     66.76
# 3      [Healthcare Dividend Growth Stocks: Part 1, ET...  66.10     66.43
# 4      [Elliott Associates sues AbbVie over failed bi...  66.54     66.95
# ...                                                  ...    ...       ...
# 53107  [President Donald Trump warned Iran on Wednesd...  37.53     39.21
# 53108  [Can Donald Trump achieve what OPEC itself cou...  40.40     39.21
# 53109  [(Bloomberg) -- In Saudi Arabia, there is one ...  39.21     39.21
# 53110  [Honeywell, the big industrial and aerospace f...  39.21     39.21
# 53111  [Oil major ExxonMobil has not changed its cape...  39.21     39.21
#
#        price_diff  label
# 0           -0.40      0
# 1           -0.44      0
# 2            0.19      1
# 3            0.33      1
# 4            0.41      1
# ...           ...    ...
# 53107        1.68      1
# 53108       -1.19      0
# 53109        0.00      0
# 53110        0.00      0
# 53111        0.00      0
#
# [53112 rows x 8 columns]

# %%
result_df = label_df.drop("price_diff", axis =1)
result_df
# Out:
#       ticker        date                                              title  \
# 0       ABBV  2016-08-01                 [Company News for August 01, 2016]
# 1       ABBV  2016-08-02                 [Company News for August 01, 2016]
# 2       ABBV  2016-08-03                 [Company News for August 01, 2016]
# 3       ABBV  2016-08-04  [Healthcare Dividend Growth Stocks: Part 1, ET...
# 4       ABBV  2016-08-05  [Elliott Associates sues AbbVie over failed bi...
# ...      ...         ...                                                ...
# 53107    XOM  2020-04-01  [Trump warns of ‘heavy price’ if Iran attacks ...
# 53108    XOM  2020-04-02  [Oil in Sudden U-Turn After Trump Touts Produc...
# 53109    XOM  2020-04-03  [Trump Faces Bitterly Divided Oil Producers in...
# 53110    XOM  2020-04-04  [Exclusive: Honeywell Pressures Suppliers To C...
# 53111    XOM  2020-04-05  [The Oil Giant Drowning In Debt, Big Oil Raise...
#
#                                        short_description  close  shiftday  \
# 0      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.94     66.54
# 1      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.78     66.34
# 2      [•    Shares of Xerox Corp ( XRX ) gained 3.9%...  66.57     66.76
# 3      [Healthcare Dividend Growth Stocks: Part 1, ET...  66.10     66.43
# 4      [Elliott Associates sues AbbVie over failed bi...  66.54     66.95
# ...                                                  ...    ...       ...
# 53107  [President Donald Trump warned Iran on Wednesd...  37.53     39.21
# 53108  [Can Donald Trump achieve what OPEC itself cou...  40.40     39.21
# 53109  [(Bloomberg) -- In Saudi Arabia, there is one ...  39.21     39.21
# 53110  [Honeywell, the big industrial and aerospace f...  39.21     39.21
# 53111  [Oil major ExxonMobil has not changed its cape...  39.21     39.21
#
#        label
# 0          0
# 1          0
# 2          1
# 3          1
# 4          1
# ...      ...
# 53107      1
# 53108      0
# 53109      0
# 53110      0
# 53111      0
#
# [53112 rows x 7 columns]

# %%
result_df['short_description'] = result_df['short_description'].apply(lambda x: list(set(x)))
result_df['short_description'] = [','.join(map(str, i)) for i in df['short_description']]
result_df
# Out:
#       ticker        date                                              title  \
# 0       ABBV  2016-08-01                 [Company News for August 01, 2016]
# 1       ABBV  2016-08-02                 [Company News for August 01, 2016]
# 2       ABBV  2016-08-03                 [Company News for August 01, 2016]
# 3       ABBV  2016-08-04  [Healthcare Dividend Growth Stocks: Part 1, ET...
# 4       ABBV  2016-08-05  [Elliott Associates sues AbbVie over failed bi...
# ...      ...         ...                                                ...
# 53107    XOM  2020-04-01  [Trump warns of ‘heavy price’ if Iran attacks ...
# 53108    XOM  2020-04-02  [Oil in Sudden U-Turn After Trump Touts Produc...
# 53109    XOM  2020-04-03  [Trump Faces Bitterly Divided Oil Producers in...
# 53110    XOM  2020-04-04  [Exclusive: Honeywell Pressures Suppliers To C...
# 53111    XOM  2020-04-05  [The Oil Giant Drowning In Debt, Big Oil Raise...
#
#                                        short_description  close  shiftday  \
# 0      •    Shares of Xerox Corp ( XRX ) gained 3.9% ...  66.94     66.54
# 1      •    Shares of Xerox Corp ( XRX ) gained 3.9% ...  66.78     66.34
# 2      •    Shares of Xerox Corp ( XRX ) gained 3.9% ...  66.57     66.76
# 3      Healthcare Dividend Growth Stocks: Part 1,ETF’...  66.10     66.43
# 4      Elliott Associates sues AbbVie over failed bid...  66.54     66.95
# ...                                                  ...    ...       ...
# 53107  President Donald Trump warned Iran on Wednesda...  37.53     39.21
# 53108  Can Donald Trump achieve what OPEC itself coul...  40.40     39.21
# 53109  (Bloomberg) -- In Saudi Arabia, there is one o...  39.21     39.21
# 53110  Honeywell, the big industrial and aerospace fi...  39.21     39.21
# 53111  Oil major ExxonMobil has not changed its capex...  39.21     39.21
#
#        label
# 0          0
# 1          0
# 2          1
# 3          1
# 4          1
# ...      ...
# 53107      1
# 53108      0
# 53109      0
# 53110      0
# 53111      0
#
# [53112 rows x 7 columns]

# %%
from nltk.book import *

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
def sentiment(df):
    sid = SentimentIntensityAnalyzer()
    df['sentiment'] = df['short_description'].apply(lambda x:sid.polarity_scores(str(x)))
    df['pos'] = df['sentiment'].apply(lambda x: x['pos'])
    df['neu'] = df['sentiment'].apply(lambda x: x['neu'])
    df['neg'] = df['sentiment'].apply(lambda x: x['neg'])
    df['compound'] = df['sentiment'].apply(lambda x: x['compound'])
    
    df = df[['date','short_description','label','pos','neu','neg','compound']]
    return df

# %%
sentiment(result_df)
# Out:
#              date                                  short_description  label  \
# 0      2016-08-01  •    Shares of Xerox Corp ( XRX ) gained 3.9% ...      0
# 1      2016-08-02  •    Shares of Xerox Corp ( XRX ) gained 3.9% ...      0
# 2      2016-08-03  •    Shares of Xerox Corp ( XRX ) gained 3.9% ...      1
# 3      2016-08-04  Healthcare Dividend Growth Stocks: Part 1,ETF’...      1
# 4      2016-08-05  Elliott Associates sues AbbVie over failed bid...      1
# ...           ...                                                ...    ...
# 53107  2020-04-01  President Donald Trump warned Iran on Wednesda...      1
# 53108  2020-04-02  Can Donald Trump achieve what OPEC itself coul...      0
# 53109  2020-04-03  (Bloomberg) -- In Saudi Arabia, there is one o...      0
# 53110  2020-04-04  Honeywell, the big industrial and aerospace fi...      0
# 53111  2020-04-05  Oil major ExxonMobil has not changed its capex...      0
#
#          pos    neu    neg  compound
# 0      0.286  0.638  0.077    0.7351
# 1      0.286  0.638  0.077    0.7351
# 2      0.286  0.638  0.077    0.7351
# 3      0.061  0.939  0.000    0.3818
# 4      0.053  0.828  0.119   -0.7964
# ...      ...    ...    ...       ...
# 53107  0.070  0.818  0.112   -0.9919
# 53108  0.086  0.868  0.046    0.9931
# 53109  0.134  0.803  0.063    0.9998
# 53110  0.038  0.884  0.078   -0.2263
# 53111  0.000  0.839  0.161   -0.8553
#
# [53112 rows x 7 columns]
